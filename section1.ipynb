# %%
num1=float(input("enter the first number"))
num2=float(input("enter the second number"))
num3=float(input("enter the third number"))

if num1==num2 or num1 ==num3 or num2==num3 :
    print("the sum of theses numbers is zero as there is two equal values")
else:
    print("sum:", num1+num2+num3)
# Out:
# enter the first number 6
# enter the second number 2
# enter the third number 8
# sum: 16.0

# %%
for i in range(1, 51):
    if i%3==0 :
        print(i)
"""range() with single argument is list of integer numbers from 0 to less than this argument value
    range() with two arguments (start, stop) return list of numbers between start(inclusive) and stop(exclusive) and the step will be by default 1
    range() with three arguments (start, stop, step) """
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
